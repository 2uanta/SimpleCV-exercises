# %%
from SimpleCV import Image as cvImage, Display 
from IPython.core.display import Image
img = cvImage("espresso.jpg")
data =  img.getEXIFData()
import pprint
pp = pprint.PrettyPrinter(indent=4)
#pp.pprint(data)

#winsize = (480, 480)
#display = Display(winsize)
#img1.save(display)
i = Image(filename="espresso.jpg",width=80)
i

# %%
print img.getEXIFData

# %%
Display().quit
